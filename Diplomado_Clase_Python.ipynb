# %% [markdown]
# <a href="https://colab.research.google.com/github/LizethAlvarezM/DiplomadoCMD/blob/main/Diplomado_Clase_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.DataFrame().dtypes
# Out:
# Series([], dtype: object)

# %%
data =[1,2,3,4,5]
pd.DataFrame(data)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
pd.DataFrame(data,columns=["Numeros"])
# Out:
#    Numeros
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
pd.DataFrame(data,columns=["Numeros"], index=["Lun", "Mar", "Mier", "Jue", "Vie"])
# Out:
#       Numeros
# Lun         1
# Mar         2
# Mier        3
# Jue         4
# Vie         5

# %%
data =[["Juan", 20],["Luisa",30],["Ricardo",25]]
pd.DataFrame(data,columns=["Nombre","Edad"])
# Out:
#     Nombre  Edad
# 0     Juan    20
# 1    Luisa    30
# 2  Ricardo    25

# %%
data ={"Nombre":["Juan","Luisa","Ricardo"],
       "Edad":[20,30,25],
       "Sexo":["H","M","H"]}
pd.DataFrame(data)
# Out:
#     Nombre  Edad Sexo
# 0     Juan    20    H
# 1    Luisa    30    M
# 2  Ricardo    25    H

# %%
pd.read_excel("/content/tote_shipment.xlsx")
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My \Drive/Diplomado
# Out:
# /content/drive/My Drive/Diplomado

# %%
df = pd.read_excel("tote_shipment.xlsx")
df
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df = pd.read_excel("tote_shipment.xlsx")
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# ...

# %%
df_1 = pd.read_excel("tote_shipment.xlsx", header=None).head()
df_1
# Out:
#            0         1                                2     3   \
# 0  asset_type  asset_id                           tag_id  Site
# 1        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 2        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 3        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 4        tote         2  (01)00850027865010(21)0082T0219  DC 1
#
#                4             5                           6         7   \
# 0            Zone     device_id                    time_est       lat
# 1  dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2  dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3  dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4  dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
#
#          8              9              10
# 0       lng  Temperature_C  Temperature_F
# 1 -65.68902             23           73.4
# ...

# %%
df_1.columns = ["Tipo","Asset ID","Tag ID","Sitio","Zona","Device"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-9694f04ecdeb> in <cell line: 1>()
# ----> 1 df_1.columns = ["Tipo","Asset ID","Tag ID","Sitio","Zona","Device"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5913         try:
#    5914             object.__getattribute__(self, name)
# -> 5915             return object.__setattr__(self, name, value)
#    5916         except AttributeError:
#    5917             pass
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     821     def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822         labels = ensure_index(labels)
# ...

# %%
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# ...

# %%
df.columns
# Out:
# Index(['asset_type', 'asset_id', 'tag_id', 'Site', 'Zone', 'device_id',
#        'time_est', 'lat', 'lng', 'Temperature_C', 'Temperature_F'],
#       dtype='object')

# %%
df = df.rename(columns = {"asset_type":"tipo","Site":"Sitio","Zone":"Zona"})
df
# Out:
#         tipo  asset_id                           tag_id  Sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zona     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# ...

# %%
df.shape
# Out:
# (130061, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tipo           130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Sitio          130061 non-null  object
#  4   Zona           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   time_est       130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 10.9+ MB

# %%
df.describe()
# Out:
#             asset_id            lat            lng  Temperature_C  \
# count  130061.000000  130061.000000  130061.000000  130061.000000
# mean      105.184475      47.760258     -65.668955      25.874445
# std        61.459262       0.019223       0.049597       2.795208
# min         2.000000      47.748780     -65.762200      19.000000
# 25%        58.000000      47.749230     -65.641010      24.000000
# 50%        84.000000      47.749230     -65.641010      25.000000
# 75%       167.000000      47.749388     -65.641010      27.500000
# max       205.000000      47.805010     -65.640330      44.000000
#
#        Temperature_F
# count  130061.000000
# mean       78.574000
# std         5.031375
# min        66.200000
# 25%        75.200000
# 50%        77.000000
# 75%        81.500000
# max       111.200000

# %%
df.describe(include='all')
# Out:
# <ipython-input-36-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#           tipo       asset_id                           tag_id   Sitio  \
# count   130061  130061.000000                           130061  130061
# unique       1            NaN                               34       4
# top       tote            NaN  (01)00850027865010(21)0082T0953   Store
# freq    130061            NaN                             6602   96897
# first      NaN            NaN                              NaN     NaN
# last       NaN            NaN                              NaN     NaN
# mean       NaN     105.184475                              NaN     NaN
# std        NaN      61.459262                              NaN     NaN
# ...

# %%
df["asset_id"].unique()
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
df["asset_id"].nunique()
# Out:
# 18

# %%
df.asset_id.unique()
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
df.tag_id.unique()
# Out:
# array(['(01)00850027865010(21)0082T0219',
#        '(01)00850027865010(21)0082T0670',
#        '(01)00850027865010(21)0082T0017',
#        '(01)00850027865010(21)0082T0953',
#        '(01)00850027865010(21)0082T0685',
#        '(01)00850027865010(21)0082T1101',
#        '(01)00850027865010(21)0082T0040',
#        '(01)00850027865010(21)0082T0495',
#        '(01)00850027865010(21)0082T0485',
#        '(01)00850027865010(21)0082T0525',
#        '(01)00850027865010(21)0082T0193',
#        '(01)00850027865010(21)0082T0194',
#        '(01)00850027865010(21)0082T0415',
#        '(01)00850027865010(21)0082T1188',
#        '(01)00850027865010(21)0082T0117',
#        '(01)00850027865010(21)0082T0932',
#        '(01)00850027865010(21)0082T0329',
#        '(01)00850027865010(21)0082T0458',
#        '(01)00850027865010(21)0082T0609',
#        '(01)00850027865010(21)0082T0260',
#        '(01)00850027865010(21)0082T0261',
#        '(01)00850027865010(21)0082T0196',
# ...

# %%
df.tag_id.nunique()
# Out:
# 34

# %%
df.sitio.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-059c21d9b9ce> in <cell line: 1>()
# ----> 1 df.sitio.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sitio'

# %%
df.zona.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-8164ac96fc97> in <cell line: 1>()
# ----> 1 df.zona.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'zona'

# %%
df.grouby(['asset_Id']).nunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-0a9351c1264e> in <cell line: 1>()
# ----> 1 df.grouby(['asset_Id']).nunique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'grouby'

# %%
pd.DataFrame(df.groupby(['asset_id'])['tag_id'])

# %%
pd.DataFrame(df.groupby(['sitio'])['zona'].nunique()).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-cf1a14ac5b15> in <cell line: 1>()
# ----> 1 pd.DataFrame(df.groupby(['sitio'])['zona'].nunique()).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     963             from pandas.core.groupby.grouper import get_grouper
#     964
# --> 965             grouper, exclusions, obj = get_grouper(
# ...

# %%
df_2 = df_1.fillna('NA')
df_2
# Out:
#            0         1                                2     3   \
# 0  asset_type  asset_id                           tag_id  Site
# 1        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 2        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 3        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 4        tote         2  (01)00850027865010(21)0082T0219  DC 1
#
#                4             5                           6         7   \
# 0            Zone     device_id                    time_est       lat
# 1  dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2  dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3  dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4  dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
#
#          8              9              10
# 0       lng  Temperature_C  Temperature_F
# 1 -65.68902             23           73.4
# ...

# %%
df_3 = df_1.copy()
df_3['Zone'] = df_3.Zone.fillna('Na')
df_3['Temp_C'] = df_3.Temp_C.fillna(0)
df_3['Temp_F'] = df_3.Temp_F.fillna(df.Temperature_F.median())
df_3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-92d81d1b058c> in <cell line: 2>()
#       1 df_3 = df_1.copy()
# ----> 2 df_3['Zone'] = df_3.Zone.fillna('Na')
#       3 df_3['Temp_C'] = df_3.Temp_C.fillna(0)
#       4 df_3['Temp_F'] = df_3.Temp_F.fillna(df.Temperature_F.median())
#       5 df_3
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Zone'

# %%
df_1[~df_1.Temp_C]
